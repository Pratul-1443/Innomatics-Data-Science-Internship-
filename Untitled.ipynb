# %%
import pandas as pd

# %%
data = pd.read_csv("movies.csv")

# %%
data
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
shape = data.shape
 print("Shape = {}".format(shape))
# Out:
# Shape = (9742, 3)

# %%
shape
# Out:
# (9742, 3)

# %%
ds2=pd.read_csv("ratings.csv")

# %% [markdown]
# ds2

# %%
ds2
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
a=ds2.userId.unique()

# %%
ds2.nunique()
# Out:
# userId         610
# movieId       9724
# rating          10
# timestamp    85043
# dtype: int64

# %%
ds2.sort('rating', ascending = False).head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18656\556776610.py in ?()
# ----> 1 ds2.sort('rating', ascending = False).head(5)
#
# C:\python_\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
ds2
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
ds2.rating.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18656\3761554406.py in ?()
# ----> 1 ds2.rating.sort()
#
# C:\python_\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'sort'

# %%
ds2.sort_values(by=['rating'])
# Out:
#        userId  movieId  rating   timestamp
# 3752       22    53519     0.5  1268727137
# 60861     393     5445     0.5  1430506636
# 47025     307     2017     0.5  1186173639
# 22446     153     1198     0.5  1525548264
# 60865     393     5902     0.5  1430507509
# ...       ...      ...     ...         ...
# 90260     587       50     5.0   953141366
# 90261     587       58     5.0   953141592
# 17061     108     5303     5.0  1042839719
# 90266     587      236     5.0   953139541
# 81530     516     4429     5.0   994625299
#
# [100836 rows x 4 columns]

# %%
import pandas as pd

ratings_df = pd.read_csv('ratings.csv')
movies_df = pd.read_csv('movies.csv')
rating_counts = ratings_df.groupby('movieId').size().reset_index(name='rating_count')
max_rated_movie_id = rating_counts.loc[rating_counts['rating_count'].idxmax()]['movieId']

max_rated_movie_title = movies_df.loc[movies_df['movieId'] == max_rated_movie_id]['title'].values[0]

max_rated_movie_title
# Out:
# The movie with the maximum number of user ratings is: Forrest Gump (1994)

# %%
rating_counts
# Out:
#       movieId  rating_count
# 0           1           215
# 1           2           110
# 2           3            52
# 3           4             7
# 4           5            49
# ...       ...           ...
# 9719   193581             1
# 9720   193583             1
# 9721   193585             1
# 9722   193587             1
# 9723   193609             1
#
# [9724 rows x 2 columns]

# %%
matrix_movie_id = movies_df.loc[movies_df['title'] == 'Matrix, The (1999)']['movieId'].values[0]

matrix_tags = tags_df.loc[tags_df['movieId'] == matrix_movie_id]['tag'].unique()

matrix_tags
# Out:
# Tags for 'Matrix, The (1999)': ['martial arts' 'sci-fi' 'alternate universe' 'philosophy'
#  'post apocalyptic']

# %%
terminator_movie_id = movies_df.loc[movies_df['title'] == 'Terminator 2: Judgment Day (1991)']['movieId'].values[0]

terminator_ratings = ratings_df.loc[ratings_df['movieId'] == terminator_movie_id]['rating']
average_rating = terminator_ratings.mean()
average_rating
# Out:
# The average user rating for 'Terminator 2: Judgment Day (1991)' is: 3.970982142857143

# %%
fight_club_movie_id = movies_df.loc[movies_df['title'] == 'Fight Club (1999)']['movieId'].values[0]

fight_club_ratings = ratings_df.loc[ratings_df['movieId'] == fight_club_movie_id]['rating']

plt.figure(figsize=(10, 6))
plt.hist(fight_club_ratings, bins=10, edgecolor='black')
plt.title('Distribution of User Ratings for "Fight Club (1999)"')
plt.xlabel('Rating')
plt.ylabel('Number of Ratings')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 8))
plt.boxplot(fight_club_ratings, vert=False)
plt.title('Box Plot of User Ratings for "Fight Club (1999)"')
plt.xlabel('Rating')
plt.grid(True)
plt.show()

# %%
grouped_ratings = ratings_df.groupby('movieId').agg(
    rating_count=('rating', 'size'),
    average_rating=('rating', 'mean')
).reset_index()

movies_with_ratings = pd.merge(movies_df, grouped_ratings, on='movieId')
filtered_movies = movies_with_ratings[movies_with_ratings['rating_count'] > 50]

print(filtered_movies[['movieId', 'title', 'rating_count', 'average_rating']])
# Out:
#       movieId                             title  rating_count  average_rating
# 0           1                  Toy Story (1995)           215        3.920930
# 1           2                    Jumanji (1995)           110        3.431818
# 2           3           Grumpier Old Men (1995)            52        3.259615
# 5           6                       Heat (1995)           102        3.946078
# 6           7                    Sabrina (1995)            54        3.185185
# ...       ...                               ...           ...             ...
# 8287   106782   Wolf of Wall Street, The (2013)            54        3.916667
# 8354   109374  Grand Budapest Hotel, The (2014)            52        3.778846
# 8358   109487               Interstellar (2014)            73        3.993151
# 8457   112852    Guardians of the Galaxy (2014)            59        4.050847
# 8673   122904                   Deadpool (2016)            54        3.833333
#
# [436 rows x 4 columns]

# %%
grouped_ratings = ratings_df.groupby('movieId').agg(
    rating_count=('rating', 'size'),
    average_rating=('rating', 'mean')
).reset_index()

movies_with_ratings = pd.merge(movies_df, grouped_ratings, on='movieId')

filtered_movies = movies_with_ratings[movies_with_ratings['rating_count'] > 50]
most_popular_movie = filtered_movies.loc[filtered_movies['average_rating'].idxmax()]

print(most_popular_movie['title'], most_popular_movie['average_rating'])
# Out:
# The most popular movie based on average user ratings is 'Shawshank Redemption, The (1994)' with an average rating of 4.43.

# %%
grouped_ratings = ratings_df.groupby('movieId').agg(
    rating_count=('rating', 'size'),
    average_rating=('rating', 'mean')
).reset_index()

movies_with_ratings = pd.merge(movies_df, grouped_ratings, on='movieId')

filtered_movies = movies_with_ratings[movies_with_ratings['rating_count'] > 50]

top_5_movies = filtered_movies.sort_values(by='rating_count', ascending=False).head(5)
print(top_5_movies[['movieId', 'title', 'rating_count']])
# Out:
#       movieId                             title  rating_count
# 314       356               Forrest Gump (1994)           329
# 277       318  Shawshank Redemption, The (1994)           317
# 257       296               Pulp Fiction (1994)           307
# 510       593  Silence of the Lambs, The (1991)           279
# 1938     2571                Matrix, The (1999)           278

# %%
grouped_ratings = ratings_df.groupby('movieId').agg(
    rating_count=('rating', 'size'),
    average_rating=('rating', 'mean')
).reset_index()
movies_with_ratings = pd.merge(movies_df, grouped_ratings, on='movieId')
filtered_movies = movies_with_ratings[movies_with_ratings['rating_count'] > 50]
sci_fi_movies = filtered_movies[filtered_movies['genres'].str.contains('Sci-Fi')]
third_most_popular_sci_fi = sci_fi_movies.sort_values(by='rating_count', ascending=False).iloc[2]

# Display the result
print(third_most_popular_sci_fi['title'],['rating_count'] ")
# Out:
# The third most popular Sci-Fi movie based on the number of user ratings is 'Jurassic Park (1993)' with 238 ratings.

# %%
links_df = pd.read_csv('links.csv')
filtered_movies_df = filtered_movies 

movies_with_links = pd.merge(filtered_movies_df, links_df, on='movieId')

# %%
pip install beautifulsoup4 requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
filtered_movies_df =filtered_movies
movies_with_links = pd.merge(filtered_movies_df, links_df, on='movieId')
sci_fi_movies = movies_with_links[movies_with_links['genres'].str.contains('Sci-Fi')]

# %%
import requests
from bs4 import BeautifulSoup

def scrape_imdb_rating(imdb_id):
    url = f'https://www.imdb.com/title/{imdb_id}/'
    response = requests.get(url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        rating_tag = soup.find('span', itemprop='ratingValue')
        if rating_tag:
            return float(rating_tag.get_text())
        else:
            print(f"Rating not found for IMDB ID {imdb_id}")
            return None
    else:
        print(f"Failed to retrieve page for IMDB ID {imdb_id}")
        return None

# Example usage
sci_fi_movies['imdbRating'] = sci_fi_movies['imdbId'].apply(scrape_imdb_rating)
# Drop rows with missing ratings
sci_fi_movies = sci_fi_movies.dropna(subset=['imdbRating'])

# Find the movie with the highest IMDB rating
highest_rating_movie = sci_fi_movies.loc[sci_fi_movies['imdbRating'].idxmax()]

# Get the movieId of the movie with the highest IMDB rating
highest_imdb_rating_movie_id = highest_rating_movie['movieId']
print(f"The movieId of the Sci-Fi movie with the highest IMDB rating is {highest_imdb_rating_movie_id}.")
# Out:
# Failed to retrieve page for IMDB ID 114746
# Failed to retrieve page for IMDB ID 112715
# Failed to retrieve page for IMDB ID 113481
# Failed to retrieve page for IMDB ID 113492
# Failed to retrieve page for IMDB ID 114898
# Failed to retrieve page for IMDB ID 76759
# Failed to retrieve page for IMDB ID 114069
# Failed to retrieve page for IMDB ID 111282
# Failed to retrieve page for IMDB ID 111280
# Failed to retrieve page for IMDB ID 106598
# Failed to retrieve page for IMDB ID 106697
# Failed to retrieve page for IMDB ID 107290
# Failed to retrieve page for IMDB ID 83658
# Failed to retrieve page for IMDB ID 103064
# Failed to retrieve page for IMDB ID 117705
# Failed to retrieve page for IMDB ID 116629
# Failed to retrieve page for IMDB ID 117218
# Failed to retrieve page for IMDB ID 62622
# Failed to retrieve page for IMDB ID 83866
# Failed to retrieve page for IMDB ID 96754
# Failed to retrieve page for IMDB ID 80684
# Failed to retrieve page for IMDB ID 88846
# ...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Load the CSV files
links_df = pd.read_csv('links.csv')
filtered_movies_df = filtered_movies
# Merge to get IMDB IDs for filtered movies
movies_with_links = pd.merge(filtered_movies_df, links_df, on='movieId')

def scrape_imdb_rating(imdb_id):
    url = f'https://www.imdb.com/title/{imdb_id}/'
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for HTTP errors

        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # Extract IMDB rating
            rating_tag = soup.find('span', itemprop='ratingValue')
            if rating_tag:
                return float(rating_tag.get_text())
            else:
                print(f"Rating not found for IMDB ID {imdb_id}")
                return None
        else:
            print(f"Failed to retrieve page for IMDB ID {imdb_id}. Status code: {response.status_code}")
            return None
    except requests.RequestException as e:
        print(f"Request failed for IMDB ID {imdb_id}. Error: {e}")
        return None

# Apply the function to get IMDB ratings
movies_with_links['imdbRating'] = movies_with_links['imdbId'].apply(scrape_imdb_rating)

# Drop rows with missing ratings
movies_with_links = movies_with_links.dropna(subset=['imdbRating'])

# Find the movie with the highest IMDB rating
if not movies_with_links.empty:
    highest_rating_movie = movies_with_links.loc[movies_with_links['imdbRating'].idxmax()]
    highest_imdb_rating_movie_id = highest_rating_movie['movieId']
    print(f"The movieId of the movie with the highest IMDB rating is {highest_imdb_rating_movie_id}.")
else:
    print("No movies with valid IMDB ratings found.")
# Out:
# Request failed for IMDB ID 114709. Error: 404 Client Error:  for url: https://www.imdb.com/title/114709/
# Request failed for IMDB ID 113497. Error: 404 Client Error:  for url: https://www.imdb.com/title/113497/
# Request failed for IMDB ID 113228. Error: 404 Client Error:  for url: https://www.imdb.com/title/113228/
# Request failed for IMDB ID 113277. Error: 404 Client Error:  for url: https://www.imdb.com/title/113277/
# Request failed for IMDB ID 114319. Error: 404 Client Error:  for url: https://www.imdb.com/title/114319/
# Request failed for IMDB ID 113189. Error: 404 Client Error:  for url: https://www.imdb.com/title/113189/
# Request failed for IMDB ID 112346. Error: 404 Client Error:  for url: https://www.imdb.com/title/112346/
# Request failed for IMDB ID 112641. Error: 404 Client Error:  for url: https://www.imdb.com/title/112641/
# Request failed for IMDB ID 114388. Error: 404 Client Error:  for url: https://www.imdb.com/title/114388/
# ...
